# %%
import os
os.getcwd()
# Out:
# '/Users/abdiqalaqmohamed/Desktop/DSA_2040_FS_243'

# %%
import sqlite3

conn = sqlite3.connect("retail_dw.db")
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())

conn.close()
# Out:
# []

# %%
import os
os.listdir()
# Out:
# ['schema_dw.sql ', 'retail_dw.db']
